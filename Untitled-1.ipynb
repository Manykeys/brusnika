# %%
pip install json
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
import json

# %%
f = open('employees_info.json').read()
data_table = json.loads(f)
data_table
# Out:
# {'Проектирование': {'Отдел архитектурного проектирования': {'Иванов Петр': {'Должность': 'Архитектор',
#     'Функции': ['Разработка архитектурных концепций',
#      'Проектирование зданий и сооружений',
#      'Координация проектных работ']},
#    'Смирнова Анна': {'Должность': 'Дизайнер интерьера',
#     'Функции': ['Создание дизайн-проектов интерьеров',
#      'Подбор отделочных материалов',
#      'Визуализация проектов']},
#    'Козлов Алексей': {'Должность': 'Проектировщик',
#     'Функции': ['Разработка технических заданий',
#      'Согласование проектов с заказчиками',
#      'Участие в проектировании инженерных систем']},
#    'Попова Екатерина': {'Должность': 'Ландшафтный архитектор',
#     'Функции': ['Проектирование ландшафтных композиций',
#      'Разработка садово-парковых проектов',
#      'Подбор растений и декоративных элементов']},
#    'Никитин Дмитрий': {'Должность': 'Архитектурный консультант',
# ...
